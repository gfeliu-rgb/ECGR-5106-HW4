# %% [markdown]
# # Problems 1 and 2: Character-Level Transformers
#
# Executed summary notebook for the paragraph and Tiny Shakespeare transformer experiments. The full implementation is in `src/hw4_transformers.py`.

# %% [markdown]
# ## Problem 1 Summary

# %%
# Problem 1 Summary
import pandas as pd
pd.read_csv('results/problem1_transformer_summary.csv').head(20)
# Out:
#    epoch  train_loss  valid_loss  valid_accuracy  valid_top3_accuracy  \
# 0      5    1.940157    2.195614        0.375157             0.617328
# 1      5    1.910390    2.213219        0.376618             0.606889
# 2      5    1.996892    2.284531        0.347321             0.583577
#
#    valid_perplexity            experiment  sequence_length  num_layers  \
# 0          8.985517  problem1_transformer               10           2
# 1          9.145103  problem1_transformer               20           2
# 2          9.821075  problem1_transformer               30           2
#
#    num_heads  d_model  parameter_count  approx_attention_ops  train_seconds  \
# 0          2       48            61485                562560       1.282989
# 1          2       48            61965               1144320       2.182252
# 2          2       48            62445               1745280       3.219031
#
#    inference_seconds_per_sample  vocab_size  \
# ...

# %% [markdown]
# ## Problem 2 Summary

# %%
# Problem 2 Summary
import pandas as pd
pd.read_csv('results/problem2_transformer_summary.csv').head(20)
# Out:
#    epoch  train_loss  valid_loss  valid_accuracy  valid_top3_accuracy  \
# 0      2    2.234293    2.184213        0.374812             0.603219
# 1      2    2.248132    2.189434        0.373875             0.591250
# 2      2    2.312831    2.250137        0.360687             0.587875
# 3      2    2.328832    2.288028        0.340562             0.580396
# 4      2    2.248132    2.189434        0.373875             0.591250
# 5      2    2.265898    2.227239        0.365542             0.585708
# 6      2    2.201336    2.170458        0.382958             0.595375
# 7      2    2.205179    2.166647        0.373229             0.601917
# 8      2    2.285490    2.244209        0.358362             0.584275
#
#    valid_perplexity         experiment  sequence_length  num_layers  \
# 0          8.883654  problem2_baseline               20           2
# 1          8.930159  problem2_baseline               30           2
# ...

# %% [markdown]
# ## plots/problem1_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem1_transformer_loss.png')

# %% [markdown]
# ## plots/problem2_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem2_transformer_loss.png')
