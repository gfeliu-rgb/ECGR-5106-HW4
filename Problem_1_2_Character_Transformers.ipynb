# %% [markdown]
# # Problems 1 and 2: Character-Level Transformers
#
# Executed summary notebook for the paragraph and Tiny Shakespeare transformer experiments. The full implementation is in `src/hw4_transformers.py`.

# %% [markdown]
# ## Problem 1 Summary

# %%
# Problem 1 Summary
import pandas as pd
pd.read_csv('results/problem1_transformer_summary.csv').head(20)
# Out:
#    epoch  train_loss  valid_loss  valid_accuracy  valid_top3_accuracy  \
# 0     30    0.797263    2.808278        0.470355             0.645929
# 1     30    0.519294    3.069657        0.514509             0.675052
# 2     30    0.396494    3.400901        0.513570             0.671816
#
#    valid_perplexity            experiment  sequence_length  num_layers  \
# 0         16.581347  problem1_transformer               10           2
# 1         21.534515  problem1_transformer               20           2
# 2         29.991111  problem1_transformer               30           2
#
#    num_heads  d_model  parameter_count  approx_attention_ops  train_seconds  \
# 0          2       64           106541                995840       9.585804
# 1          2       64           107181               2017280      17.168843
# 2          2       64           107821               3064320      25.344417
#
#    inference_seconds_per_sample  vocab_size  \
# 0                      0.000322          45
# 1                      0.000347          45
# 2                      0.000377          45
#
#                                     generated_output
# 0  Neracters to involves prediction in 'memore sp...
# 1  NNs are particularly well-suited for sequentia...
# 2  Ns are particularly well-suited for sequential...

# %% [markdown]
# ## Problem 2 Summary

# %%
# Problem 2 Summary
import pandas as pd
pd.read_csv('results/problem2_transformer_summary.csv').head(20)
# Out:
#    epoch  train_loss  valid_loss  valid_accuracy  valid_top3_accuracy  \
# 0      5    1.586452    2.178403        0.402200             0.631525
# 1      5    1.496647    2.215147        0.410217             0.638283
# 2      5    1.707892    2.163499        0.395033             0.635867
# 3      5    1.665415    2.196602        0.398300             0.633950
# 4      5    1.496647    2.215147        0.410217             0.638283
# 5      5    1.447024    2.284883        0.404583             0.629033
# 6      5    1.221605    2.471593        0.406117             0.628633
# 7      5    1.199474    2.453550        0.406133             0.631633
# 8      5    1.378779    2.298821        0.412740             0.640850
#
#    valid_perplexity         experiment  sequence_length  num_layers  \
# 0          8.832187  problem2_baseline               20           2
# 1          9.162760  problem2_baseline               30           2
# 2          8.701529     problem2_hyper               30           1
# 3          8.994400     problem2_hyper               30           1
# 4          9.162760     problem2_hyper               30           2
# 5          9.824536     problem2_hyper               30           2
# 6         11.841290     problem2_hyper               30           4
# 7         11.629560     problem2_hyper               30           4
# 8          9.962432     problem2_seq50               50           2
#
#    num_heads  d_model  parameter_count  approx_attention_ops  train_seconds  \
# 0          2       64           108729               2017280      12.093691
# 1          2       64           109369               3064320      17.925131
# 2          2       64            59385               1532160       9.659319
# 3          4       64            59385               1532160      10.545373
# 4          2       64           109369               3064320      17.928031
# 5          4       64           109369               3064320      19.706967
# 6          2       64           209337               6128640      34.021960
# 7          4       64           209337               6128640      37.758768
# 8          2       64           110649               5235200      31.039611
#
#    inference_seconds_per_sample  vocab_size  \
# 0                      0.000342          57
# 1                      0.000457          57
# 2                      0.000230          57
# 3                      0.000236          57
# 4                      0.000368          57
# 5                      0.000383          57
# 6                      0.000648          57
# 7                      0.000663          57
# 8                      0.000451          57
#
#                                     generated_output
# 0  NENIUS:\nIther us, thould batt fromport ther y...
# 1  NIUS:\nWhat thee gread finds and in this good ...
# 2  NIUS:\nEve s Mell, the fay the but, brell hel ...
# 3  NI youlds, I nansweir stablicit at us a speak ...
# 4  NIUS:\nWhat thee gread finds and in this good ...
# 5  NIUS:\nWho you sup, miner\nThe with se prearti...
# 6  NENIUS:\nSoft-hong what shop\nOff the storther...
# 7  No bellions I' the most of your belly,\nAnd th...
# 8  NENIUS:\nI should tenemost theas them\nI dik s...

# %% [markdown]
# ## plots/problem1_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem1_transformer_loss.png')

# %% [markdown]
# ## plots/problem2_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem2_transformer_loss.png')
