# %% [markdown]
# # Problem 4: French-to-English Transformer
#
# Executed summary notebook for the French-to-English encoder-decoder transformer grid and qualitative validation samples.

# %% [markdown]
# ## Problem 4 Summary

# %%
# Problem 4 Summary
import pandas as pd
pd.read_csv('results/problem4_transformer_summary.csv').head(20)
# Out:
#            direction  num_layers  num_heads  d_model  train_loss  valid_loss  \
# 0  French-to-English           1          2       48    5.709114    5.571853
# 1  French-to-English           1          4       48    5.677001    5.637868
# 2  French-to-English           2          2       48    5.633216    5.485101
# 3  French-to-English           2          4       48    5.660634    5.590446
# 4  French-to-English           4          2       48    5.646770    5.577074
# 5  French-to-English           4          4       48    5.676172    5.574509
#
#    valid_perplexity  sequence_accuracy     bleu4  parameter_count  \
# 0        262.920763                0.0  0.006429           209125
# 1        280.863192                0.0  0.001577           209125
# 2        241.073295                0.0  0.011807           275173
# 3        267.854997                0.0  0.006429           275173
# 4        264.297086                0.0  0.006429           407269
# 5        263.619977                0.0  0.007524           407269
#
#    approx_attention_ops  train_seconds  source_vocab  target_vocab
# 0                684288       0.281122           996           901
# 1                684288       0.290205           996           901
# 2               1368576       0.464030           996           901
# 3               1368576       0.493127           996           901
# 4               2737152       0.834762           996           901
# 5               2737152       0.901095           996           901

# %% [markdown]
# ## Problem 4 Sample L2 H2

# %%
# Problem 4 Sample L2 H2
import pandas as pd
pd.read_csv('results/problem4_fr_en_L2_H2_samples.csv').head(20)
# Out:
#            direction  num_layers  num_heads  \
# 0  French-to-English           2          2
# 1  French-to-English           2          2
# 2  French-to-English           2          2
# 3  French-to-English           2          2
# 4  French-to-English           2          2
# 5  French-to-English           2          2
# 6  French-to-English           2          2
# 7  French-to-English           2          2
#
#                                               source  \
# 0  je peux voir un grand navire de croisiere au loin
# 1                       elle cherche son chien perdu
# 2                   il a fini ses devoirs rapidement
# 3  nous preferons nous promener dans les jardins ...
# 4                    ils visitent souvent des musees
# 5                           l'ete est tres chaud ici
# 6   elle travaille a temps partiel a la bibliotheque
# 7                           la neige fond rapidement
#
#                                            reference prediction  exact_match  \
# 0      i can see a large cruise ship in the distance        she        False
# 1                    she is looking for her lost dog        she        False
# 2                   he finished his homework quickly        she        False
# 3  we prefer walking through the quiet botanical ...        she        False
# 4                           they visit museums often        the        False
# 5                        the summer is very hot here        she        False
# 6                 she works part time at the library        she        False
# 7                           the snow is melting fast        she        False
#
#    sentence_bleu4
# 0        0.000062
# 1        0.001474
# 2        0.009158
# 3        0.000456
# 4        0.024894
# 5        0.003369
# 6        0.001474
# 7        0.009158

# %% [markdown]
# ## plots/problem4_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem4_transformer_loss.png')

# %% [markdown]
# ## plots/problem4_bleu.png

# %%
from IPython.display import Image
Image(filename='plots/problem4_bleu.png')
