# %% [markdown]
# # Problem 3: English-to-French Transformer
#
# Executed summary notebook for the English-to-French encoder-decoder transformer grid and qualitative validation samples.

# %% [markdown]
# ## Problem 3 Summary

# %%
# Problem 3 Summary
import pandas as pd
pd.read_csv('results/problem3_transformer_summary.csv').head(20)
# Out:
#            direction  num_layers  num_heads  d_model  train_loss  valid_loss  \
# 0  English-to-French           1          2       64    0.514509    5.131718
# 1  English-to-French           1          4       64    0.433230    5.008451
# 2  English-to-French           2          2       64    0.368690    5.041779
# 3  English-to-French           2          4       64    0.384254    5.101949
# 4  English-to-French           4          2       64    0.730285    4.734639
# 5  English-to-French           4          4       64    0.621558    4.860914
#
#    valid_perplexity  sequence_accuracy     bleu4  parameter_count  \
# 0        169.307747           0.009009  0.245978           313380
# 1        149.672648           0.000000  0.229018           313380
# 2        154.745073           0.000000  0.244090           430116
# 3        164.341919           0.000000  0.253907           430116
# 4        113.822312           0.000000  0.217296           663588
# 5        129.142120           0.000000  0.243898           663588
#
#    approx_attention_ops  train_seconds  source_vocab  target_vocab
# 0               1207296       6.540213           901           996
# 1               1207296       6.601691           901           996
# 2               2414592      10.567999           901           996
# 3               2414592      11.041880           901           996
# 4               4829184      18.608521           901           996
# 5               4829184      19.486485           901           996

# %% [markdown]
# ## Problem 3 Sample L2 H4

# %%
# Problem 3 Sample L2 H4
import pandas as pd
pd.read_csv('results/problem3_en_fr_L2_H4_samples.csv').head(20)
# Out:
#            direction  num_layers  num_heads  \
# 0  English-to-French           2          4
# 1  English-to-French           2          4
# 2  English-to-French           2          4
# 3  English-to-French           2          4
# 4  English-to-French           2          4
# 5  English-to-French           2          4
# 6  English-to-French           2          4
# 7  English-to-French           2          4
#
#                                               source  \
# 0      i can see a large cruise ship in the distance
# 1                    she is looking for her lost dog
# 2                   he finished his homework quickly
# 3  we prefer walking through the quiet botanical ...
# 4                           they visit museums often
# 5                        the summer is very hot here
# 6                 she works part time at the library
# 7                           the snow is melting fast
#
#                                            reference  \
# 0  je peux voir un grand navire de croisiere au loin
# 1                       elle cherche son chien perdu
# 2                   il a fini ses devoirs rapidement
# 3  nous preferons nous promener dans les jardins ...
# 4                    ils visitent souvent des musees
# 5                           l'ete est tres chaud ici
# 6   elle travaille a temps partiel a la bibliotheque
# 7                           la neige fond rapidement
#
#                                           prediction  exact_match  \
# 0  je veux boire un verre de jazz en argent au ci...        False
# 1                elle cherche son chat perdu partout        False
# 2  il a termine son test en avance en avance sur ...        False
# 3  nous avons traverse la rue bondee a l'ecole le...        False
# 4                           ils sont alles au cinema        False
# 5                             le pain est tres sucre        False
# 6  elle travaille a temps partiel comme guide tou...        False
# 7            le chien dort sur la piscine est degage        False
#
#    sentence_bleu4
# 0        0.143231
# 1        0.434721
# 2        0.136744
# 3        0.139508
# 4        0.273012
# 5        0.359304
# 6        0.587395
# 7        0.160366

# %% [markdown]
# ## plots/problem3_transformer_loss.png

# %%
from IPython.display import Image
Image(filename='plots/problem3_transformer_loss.png')

# %% [markdown]
# ## plots/problem3_bleu.png

# %%
from IPython.display import Image
Image(filename='plots/problem3_bleu.png')
